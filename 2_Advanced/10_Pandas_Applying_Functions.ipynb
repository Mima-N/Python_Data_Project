# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['salary_year_avg'][df['salary_year_avg'].notna()]
df['job_skills'][df['job_skills'].isna()]
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %% [markdown]
# # Calculate Project Salary Next Year

# %%
# using the apply function with a calculated function
df_salary = df[df['salary_year_avg'].notna()].copy()

def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
# using the apply function with an anonymous function like lambda

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary * 1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
# simple method without apply function
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'] * 1.03

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['job_skills'][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
import ast

ast.literal_eval(df['job_skills'][1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
# to apply the ast.literal_eval function to the entire job skills column
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
# to confirm it worked
df['job_skills'][1]
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
# df[pd.isna(df['job_skills'])] # or df[df['job_skills'].isna()]

# %%
# doing the same with a lambda function
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
df['job_skills'][1]
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %% [markdown]
# # Calculate projected salary next year
# - Senior roles assume 5%
# - other roles assume 3%

# %%
# using the applying function on rows 
def projected_salary(row):
    if 'Senior' in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']


df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis=1)

df_salary.iloc[200:250][['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#                 job_title_short  salary_year_avg  salary_year_inflated
# 5554           Business Analyst          64600.0             66538.000
# 5579      Senior Data Scientist         170000.0            178500.000
# 5580              Data Engineer         200000.0            206000.000
# 5628             Data Scientist         361000.0            371830.000
# 5658       Senior Data Engineer         200000.0            210000.000
# 5684              Data Engineer         125000.0            128750.000
# 5688      Senior Data Scientist         180000.0            189000.000
# 5703               Data Analyst          65000.0             66950.000
# 5709             Data Scientist         192000.0            197760.000
# 5795              Data Engineer         100000.0            103000.000
# 5809              Data Engineer         125000.0            128750.000
# 5829              Data Engineer         100000.0            103000.000
# 5839               Data Analyst          67500.0             69525.000
# 5862  Machine Learning Engineer         325000.0            334750.000
# 5887              Data Engineer         122500.0            126175.000
# 5946              Data Engineer         136000.0            140080.000
# 5949             Data Scientist         160000.0            164800.000
# 6046             Data Scientist         115000.0            118450.000
# 6233              Data Engineer         150000.0            154500.000
# 6263              Data Engineer         165000.0            169950.000
# 6305             Data Scientist         170000.0            175100.000
# 6325              Data Engineer         147500.0            151925.000
# 6350             Data Scientist         250000.0            257500.000
# 6382              Data Engineer         110000.0            113300.000
# 6431              Data Engineer          96760.5             99663.315
# 6442              Data Engineer         137500.0            141625.000
# 6471              Data Engineer         132000.0            135960.000
# 6496      Senior Data Scientist         129000.0            135450.000
# 6500              Data Engineer         144820.0            149164.600
# 6525           Business Analyst          63000.0             64890.000
# 6567               Data Analyst          56700.0             58401.000
# 6575             Data Scientist         176273.5            181561.705
# 6615              Data Engineer         100000.0            103000.000
# 6707  Machine Learning Engineer          56700.0             58401.000
# 6748           Business Analyst         105000.0            108150.000
# 6755             Data Scientist          90000.0             92700.000
# 6825        Senior Data Analyst          84039.0             88240.950
# 6828             Data Scientist         110000.0            113300.000
# 6880             Data Scientist         234000.0            241020.000
# 6895       Senior Data Engineer         185000.0            194250.000
# 6941              Data Engineer         147500.0            151925.000
# 7001               Data Analyst         134984.0            139033.520
# 7006       Senior Data Engineer         136500.0            143325.000
# 7081               Data Analyst          76007.0             78287.210
# 7090              Data Engineer         284016.0            292536.480
# 7092             Data Scientist         285500.0            294065.000
# 7095             Data Scientist         123750.0            127462.500
# 7118             Data Scientist         167500.0            172525.000
# 7140       Senior Data Engineer         124500.0            130725.000
# 7170       Senior Data Engineer          89100.0             93555.000

# %%
# using the apply function with an anonymous function like lambda on rows

df_salary['salary_year_inflated'] = df_salary.apply(lambda row: 1.05 * row['salary_year_avg'] if 'Senior' in row['job_title_short'] else 1.03 * row['salary_year_avg'], axis=1)

df_salary.iloc[200:250]
# Out:
#                 job_title_short  \
# 5554           Business Analyst
# 5579      Senior Data Scientist
# 5580              Data Engineer
# 5628             Data Scientist
# 5658       Senior Data Engineer
# 5684              Data Engineer
# 5688      Senior Data Scientist
# 5703               Data Analyst
# 5709             Data Scientist
# 5795              Data Engineer
# 5809              Data Engineer
# 5829              Data Engineer
# 5839               Data Analyst
# 5862  Machine Learning Engineer
# 5887              Data Engineer
# 5946              Data Engineer
# 5949             Data Scientist
# 6046             Data Scientist
# 6233              Data Engineer
# 6263              Data Engineer
# 6305             Data Scientist
# 6325              Data Engineer
# 6350             Data Scientist
# 6382              Data Engineer
# 6431              Data Engineer
# 6442              Data Engineer
# 6471              Data Engineer
# 6496      Senior Data Scientist
# 6500              Data Engineer
# 6525           Business Analyst
# 6567               Data Analyst
# 6575             Data Scientist
# 6615              Data Engineer
# 6707  Machine Learning Engineer
# 6748           Business Analyst
# 6755             Data Scientist
# 6825        Senior Data Analyst
# 6828             Data Scientist
# 6880             Data Scientist
# 6895       Senior Data Engineer
# 6941              Data Engineer
# 7001               Data Analyst
# 7006       Senior Data Engineer
# 7081               Data Analyst
# 7090              Data Engineer
# 7092             Data Scientist
# 7095             Data Scientist
# 7118             Data Scientist
# 7140       Senior Data Engineer
# 7170       Senior Data Engineer
#
#                                               job_title  \
# 5554            Associate Business Intelligence Analyst
# 5579                              Senior Data Scientist
# 5580                                      Data Engineer
# 5628  Data Scientist Lead, Global Monetization Strat...
# 5658                               Senior Data Engineer
# 5684                                 Lead Data Engineer
# 5688                              Senior Data Scientist
# 5703                            Healthcare Data Analyst
# 5709  Data Scientist, Product Analytics (Multiple Op...
# 5795                     Higher Education Data Engineer
# 5809                                      Data Engineer
# 5829                                      Data Engineer
# 5839                                       Data Analyst
# 5862                Principal Machine Learning Engineer
# 5887                                  DBA/Data Engineer
# 5946                              Data Quality Engineer
# 5949  Government Intelligence Data Scientist / Analy...
# 6046                                     Data Scientist
# 6233                                  Sr. Data Engineer
# 6263                         Senior Staff Data Engineer
# 6305                               Data Science Manager
# 6325                       Data Engineer (Chile) Sb4375
# 6350                                     Data Scientist
# 6382                                      Data Engineer
# 6431                                      Data Engineer
# 6442  Azure Data Engineer. Job in Dallas My Valley J...
# 6471                                      Data Engineer
# 6496  Sr Data Scientist - Recommendations (Applied M...
# 6500               Data Engineer (Colorado Springs, CO)
# 6525                                         Bi Analyst
# 6567                           Data Analytics Assistant
# 6575                                Lead Data Scientist
# 6615                            Data Analytics Engineer
# 6707                             Stage Machine Learning
# 6748                            Sales Analytics Manager
# 6755        Lead Data Science Consultant - Supply Chain
# 6825                                Senior Data Analyst
# 6828                                     Data Scientist
# 6880                  Data Science Manager - TikTok Ads
# 6895                       Senior Data Science Engineer
# 6941                                      Data Engineer
# 7001  Live Streaming Revenue Product Data Analyst- USDS
# 7006                               Senior Data Engineer
# 7081                                       Data Analyst
# 7090  Distinguished Engineer, Data Architecture (Rem...
# 7092  Data Scientist, Global Monetization Strategy &...
# 7095                   Biostatistician / Data Scientist
# 7118                                Lead Data Scientist
# 7140                               Senior Data Engineer
# 7170          Senior Software Engineer (Data Analytics)
#
#                 job_location                          job_via  \
# 5554                  Canada                  via Ai-Jobs.net
# 5579           United States                     via LinkedIn
# 5580            New York, NY                         via Dice
# 5628            San Jose, CA                     via LinkedIn
# 5658     Toronto, ON, Canada                      via Ladders
# 5684           Charlotte, NC                        via BeBee
# 5688           San Diego, CA  via Central Illinois Proud Jobs
# 5703              Dallas, TX                         via Dice
# 5709            San Jose, CA                     via LinkedIn
# 5795               Tempe, AZ                       via Get.It
# 5809             Atlanta, GA                      via Ladders
# 5829        Indianapolis, IN                     via LinkedIn
# 5839            New York, NY                       via Adzuna
# 5862                Anywhere                     via LinkedIn
# 5887                Troy, MI                       via Indeed
# 5946             Milford, CT                 via ZipRecruiter
# 5949          Washington, DC                     via LinkedIn
# 6046          Pittsburgh, PA                     via LinkedIn
# 6233                Anywhere                       via Indeed
# 6263           Sunnyvale, CA                      via Ladders
# 6305                 Georgia                     via LinkedIn
# 6325         Santiago, Chile                  via Ai-Jobs.net
# 6350         Los Angeles, CA                  via IT JobServe
# 6382              California                     via LinkedIn
# 6431       Bangkok, Thailand                  via Ai-Jobs.net
# 6442              Dallas, TX         via My Valley Jobs Today
# 6471                Anywhere                 via ZipRecruiter
# 6496         Minneapolis, MN            via My ArkLaMiss Jobs
# 6500    Colorado Springs, CO            via Built In Colorado
# 6525  Amsterdam, Netherlands                  via Ai-Jobs.net
# 6567          Warsaw, Poland                  via Ai-Jobs.net
# 6575         Minneapolis, MN            via My Stateline Jobs
# 6615           Mehoopany, PA                       via Indeed
# 6707          Nantes, France                  via Ai-Jobs.net
# 6748                 Georgia                     via LinkedIn
# 6755          Cincinnati, OH                      via Ladders
# 6825            Richland, SC                       via Indeed
# 6828                Anywhere                       via Indeed
# 6880            San Jose, CA                     via LinkedIn
# 6895              California  via Central Illinois Proud Jobs
# 6941         Dublin, Ireland                  via Ai-Jobs.net
# 7001         Los Angeles, CA                     via LinkedIn
# 7006  Annapolis Junction, MD                  via Ai-Jobs.net
# 7081                Anywhere                       via Get.It
# 7090             The Bahamas                    via WSPA Jobs
# 7092            San Jose, CA                     via LinkedIn
# 7095        Temple Hills, MD                  via IT JobServe
# 7118             Raleigh, NC                     via LinkedIn
# 7140                Anywhere                       via Get.It
# 7170        Barcelona, Spain                  via Ai-Jobs.net
#
#      job_schedule_type  job_work_from_home            search_location  \
# 5554         Full-time               False                     Canada
# 5579         Full-time               False    Illinois, United States
# 5580         Full-time               False       Texas, United States
# 5628         Full-time               False  California, United States
# 5658         Full-time               False                     Canada
# 5684         Full-time               False  California, United States
# 5688         Full-time               False  California, United States
# 5703         Full-time               False       Texas, United States
# 5709         Full-time               False  California, United States
# 5795         Full-time               False    New York, United States
# 5809         Full-time               False    New York, United States
# 5829         Full-time               False  California, United States
# 5839         Full-time               False    New York, United States
# 5862         Full-time                True                      Sudan
# 5887         Full-time               False    Illinois, United States
# 5946         Full-time               False  California, United States
# 5949         Full-time               False                    Georgia
# 6046         Full-time               False    New York, United States
# 6233         Full-time                True    New York, United States
# 6263         Full-time               False     Florida, United States
# 6305         Full-time               False     Florida, United States
# 6325         Full-time               False                      Chile
# 6350         Full-time               False  California, United States
# 6382         Full-time               False                      Sudan
# 6431         Full-time               False                   Thailand
# 6442         Full-time               False     Florida, United States
# 6471         Full-time                True    Illinois, United States
# 6496         Full-time               False    Illinois, United States
# 6500         Full-time               False                    Georgia
# 6525         Full-time               False                Netherlands
# 6567         Full-time               False                     Poland
# 6575         Full-time               False    Illinois, United States
# 6615         Full-time               False    New York, United States
# 6707         Full-time               False                     France
# 6748         Full-time               False                    Georgia
# 6755         Full-time               False    Illinois, United States
# 6825         Full-time               False                    Georgia
# 6828         Full-time                True       Texas, United States
# 6880         Full-time               False  California, United States
# 6895         Full-time               False  California, United States
# 6941         Full-time               False                    Ireland
# 7001         Full-time               False  California, United States
# 7006         Full-time               False     Florida, United States
# 7081         Full-time                True     Florida, United States
# 7090         Full-time               False                    Bahamas
# 7092         Full-time               False  California, United States
# 7095         Full-time               False                    Georgia
# 7118         Full-time               False     Florida, United States
# 7140         Full-time                True    Illinois, United States
# 7170         Full-time               False                      Spain
#
#          job_posted_date  job_no_degree_mention  job_health_insurance  \
# 5554 2023-10-31 13:37:08                  False                 False
# 5579 2023-05-03 13:05:09                  False                 False
# 5580 2023-09-29 13:07:23                  False                 False
# 5628 2023-11-29 13:04:38                  False                  True
# 5658 2023-08-14 13:10:47                   True                 False
# 5684 2023-12-16 13:04:22                  False                  True
# 5688 2023-01-04 13:03:59                  False                 False
# 5703 2023-10-31 13:01:13                  False                 False
# 5709 2023-12-29 13:00:33                  False                  True
# 5795 2023-08-29 13:25:09                  False                  True
# 5809 2023-04-05 13:05:27                  False                 False
# 5829 2023-07-31 13:07:49                   True                  True
# 5839 2023-02-13 12:59:57                  False                 False
# 5862 2023-11-24 14:22:22                  False                 False
# 5887 2023-03-27 13:15:30                  False                 False
# 5946 2023-12-22 13:03:58                  False                 False
# 5949 2023-07-31 14:22:56                  False                 False
# 6046 2023-03-22 13:09:50                  False                  True
# 6233 2023-06-17 13:05:22                  False                  True
# 6263 2023-08-03 13:10:10                  False                  True
# 6305 2023-08-24 13:07:46                  False                  True
# 6325 2023-01-16 14:08:30                  False                 False
# 6350 2023-01-22 13:04:10                  False                 False
# 6382 2023-01-31 14:36:12                  False                 False
# 6431 2023-01-05 13:36:12                   True                 False
# 6442 2023-10-22 13:24:22                   True                 False
# 6471 2023-06-23 13:27:10                  False                 False
# 6496 2023-07-17 13:08:22                  False                  True
# 6500 2023-04-25 13:41:08                  False                  True
# 6525 2023-01-25 14:04:04                  False                 False
# 6567 2023-04-25 13:25:00                   True                 False
# 6575 2023-08-21 13:07:04                  False                  True
# 6615 2023-09-18 13:00:29                  False                  True
# 6707 2023-02-01 13:52:36                  False                 False
# 6748 2023-10-12 14:18:54                  False                 False
# 6755 2023-08-11 13:05:11                  False                 False
# 6825 2023-07-10 13:53:02                  False                  True
# 6828 2023-02-24 13:03:45                  False                  True
# 6880 2023-05-27 13:04:35                  False                  True
# 6895 2023-01-04 13:04:05                  False                 False
# 6941 2023-02-16 13:32:24                  False                 False
# 7001 2023-08-31 13:01:21                  False                  True
# 7006 2023-07-20 13:10:52                  False                 False
# 7081 2023-08-03 13:02:41                  False                  True
# 7090 2023-06-05 14:01:15                  False                 False
# 7092 2023-11-29 13:04:38                  False                  True
# 7095 2023-07-28 13:38:33                  False                 False
# 7118 2023-02-08 13:05:49                  False                 False
# 7140 2023-10-17 13:10:09                  False                  True
# 7170 2023-07-24 13:27:58                  False                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 5554         Canada        year          64600.0              NaN
# 5579  United States        year         170000.0              NaN
# 5580  United States        year         200000.0              NaN
# 5628  United States        year         361000.0              NaN
# 5658         Canada        year         200000.0              NaN
# 5684  United States        year         125000.0              NaN
# 5688  United States        year         180000.0              NaN
# 5703  United States        year          65000.0              NaN
# 5709  United States        year         192000.0              NaN
# 5795  United States        year         100000.0              NaN
# 5809  United States        year         125000.0              NaN
# 5829  United States        year         100000.0              NaN
# 5839  United States        year          67500.0              NaN
# 5862          Sudan        year         325000.0              NaN
# 5887  United States        year         122500.0              NaN
# 5946  United States        year         136000.0              NaN
# 5949  United States        year         160000.0              NaN
# 6046  United States        year         115000.0              NaN
# 6233  United States        year         150000.0              NaN
# 6263  United States        year         165000.0              NaN
# 6305  United States        year         170000.0              NaN
# 6325          Chile        year         147500.0              NaN
# 6350  United States        year         250000.0              NaN
# 6382          Sudan        year         110000.0              NaN
# 6431       Thailand        year          96760.5              NaN
# 6442  United States        year         137500.0              NaN
# 6471  United States        year         132000.0              NaN
# 6496  United States        year         129000.0              NaN
# 6500  United States        year         144820.0              NaN
# 6525    Netherlands        year          63000.0              NaN
# 6567         Poland        year          56700.0              NaN
# 6575  United States        year         176273.5              NaN
# 6615  United States        year         100000.0              NaN
# 6707         France        year          56700.0              NaN
# 6748  United States        year         105000.0              NaN
# 6755  United States        year          90000.0              NaN
# 6825  United States        year          84039.0              NaN
# 6828  United States        year         110000.0              NaN
# 6880  United States        year         234000.0              NaN
# 6895  United States        year         185000.0              NaN
# 6941        Ireland        year         147500.0              NaN
# 7001  United States        year         134984.0              NaN
# 7006  United States        year         136500.0              NaN
# 7081  United States        year          76007.0              NaN
# 7090        Bahamas        year         284016.0              NaN
# 7092  United States        year         285500.0              NaN
# 7095  United States        year         123750.0              NaN
# 7118  United States        year         167500.0              NaN
# 7140  United States        year         124500.0              NaN
# 7170          Spain        year          89100.0              NaN
#
#                                       company_name  \
# 5554                                      Manulife
# 5579                                       Harnham
# 5580                                         Jobot
# 5628                                        TikTok
# 5658                                       Mercury
# 5684                LTI - Larsen & Toubro Infotech
# 5688                                       Harnham
# 5703                               Citron IT, Inc.
# 5709                                        TikTok
# 5795         Get It Recruit - Educational Services
# 5809                            HD Supply Holdings
# 5829                        Pinnacle Partners, Inc
# 5839                                     Universal
# 5862                                        Storm5
# 5887                                   NuTechs LLC
# 5946                          Company Confidential
# 5949  Specialized Recruiting Group - Charlotte, NC
# 6046                               Lawrence Harvey
# 6233                                   CyberCoders
# 6263                                       Danaher
# 6305          Evolution Recruitment Solutions, USA
# 6325                                         Nisum
# 6350                           INgroovesMusicGroup
# 6382                   Northbound Executive Search
# 6431                                      Data Wow
# 6442                                         Jobot
# 6471                                      DealNews
# 6496                                        Target
# 6500                            Torch Technologies
# 6525                                        OpenUp
# 6567                               Publicis Groupe
# 6575                                        Target
# 6615                              Procter & Gamble
# 6707                                        Talend
# 6748                                 Oxenham Group
# 6755                                         84.51
# 6825                  University of South Carolina
# 6828                       Global Medical Response
# 6880                                        TikTok
# 6895                                       Harnham
# 6941                                     Version 1
# 7001                                        TikTok
# 7006                    Accenture Federal Services
# 7081                   Get It Recruit - Healthcare
# 7090                                   Capital One
# 7092                                        TikTok
# 7095                                        Leidos
# 7118                               Lawrence Harvey
# 7140       Get It Recruit - Information Technology
# 7170                                        Aetion
#
#                                              job_skills  \
# 5554                                ['sql', 'power bi']
# 5579                                  ['python', 'sql']
# 5580  ['python', 'sql', 'mongodb', 'mongodb', 'spark...
# 5628                             ['r', 'python', 'sql']
# 5658                             ['snowflake', 'react']
# 5684             ['sql', 'snowflake', 'aws', 'tableau']
# 5688  ['python', 'sql', 'aws', 'tensorflow', 'spark'...
# 5703  ['sql', 'python', 'r', 'azure', 'power bi', 't...
# 5709                             ['python', 'r', 'sql']
# 5795  ['python', 'java', 'r', 'spark', 'tensorflow',...
# 5809                                           ['flow']
# 5829                              ['sql', 'sql server']
# 5839                     ['python', 'excel', 'tableau']
# 5862  ['python', 'java', 'sql', 'aws', 'gcp', 'airfl...
# 5887  ['sql', 'python', 'sql server', 'dynamodb', 'n...
# 5946                   ['sql', 'snowflake', 'power bi']
# 5949              ['sql', 'python', 'excel', 'tableau']
# 6046  ['python', 'r', 'pytorch', 'tensorflow', 'keras']
# 6233  ['sql', 'python', 'aws', 'redshift', 'airflow'...
# 6263  ['sql', 'sql server', 'postgresql', 'dynamodb'...
# 6305       ['python', 'sql', 'aws', 'tableau', 'excel']
# 6325  ['python', 'mongo', 'gcp', 'databricks', 'kafk...
# 6350  ['python', 'r', 'julia', 'sql', 'aws', 'redshi...
# 6382  ['python', 'java', 'sql', 'azure', 'snowflake'...
# 6431  ['python', 'sql', 'aws', 'flask', 'django', 'f...
# 6442                ['sql', 'python', 'scala', 'azure']
# 6471                      ['sql', 'tableau', 'alteryx']
# 6496                ['python', 'scala', 'sql', 'spark']
# 6500                       ['sql', 'python', 'airflow']
# 6525                                 ['sql', 'tableau']
# 6567  ['r', 'python', 'spark', 'tidyverse', 'pandas'...
# 6575  ['sql', 'r', 'python', 'c', 'javascript', 'sca...
# 6615  ['sql', 'r', 'java', 'sql server', 'hadoop', '...
# 6707       ['r', 'python', 'sas', 'sas', 'gdpr', 'git']
# 6748                                        ['outlook']
# 6755                    ['python', 'r', 'sql', 'excel']
# 6825  ['sas', 'sas', 'r', 'sql', 'python', 'spss', '...
# 6828     ['sql', 'python', 'r', 'sas', 'sas', 'matlab']
# 6880          ['r', 'python', 'matlab', 'sql', 'spark']
# 6895       ['python', 'sql', 'scala', 'aws', 'pyspark']
# 6941  ['sql', 't-sql', 'shell', 'python', 'r', 'sql ...
# 7001                  ['sql', 'python', 'r', 'express']
# 7006                                              ['c']
# 7081  ['sql', 'python', 'r', 'sas', 'sas', 'matplotl...
# 7090                 ['python', 'java', 'scala', 'aws']
# 7092                                               None
# 7095                                              ['r']
# 7118                                               None
# 7140  ['sql', 'python', 'powershell', 'sql server', ...
# 7170    ['java', 'python', 'scala', 'sql', 'r', 'flow']
#
#                                         job_type_skills  salary_year_inflated
# 5554  {'analyst_tools': ['power bi'], 'programming':...             66538.000
# 5579                 {'programming': ['python', 'sql']}            178500.000
# 5580  {'databases': ['mongodb'], 'libraries': ['spar...            206000.000
# 5628            {'programming': ['r', 'python', 'sql']}            371830.000
# 5658   {'cloud': ['snowflake'], 'libraries': ['react']}            210000.000
# 5684  {'analyst_tools': ['tableau'], 'cloud': ['snow...            128750.000
# 5688  {'cloud': ['aws'], 'libraries': ['tensorflow',...            189000.000
# 5703  {'analyst_tools': ['power bi', 'tableau'], 'cl...             66950.000
# 5709            {'programming': ['python', 'r', 'sql']}            197760.000
# 5795  {'analyst_tools': ['excel', 'power bi'], 'libr...            103000.000
# 5809                                {'other': ['flow']}            128750.000
# 5829  {'databases': ['sql server'], 'programming': [...            103000.000
# 5839  {'analyst_tools': ['excel', 'tableau'], 'progr...             69525.000
# 5862  {'cloud': ['aws', 'gcp'], 'libraries': ['airfl...            334750.000
# 5887  {'async': ['jira'], 'cloud': ['aws', 'aurora',...            126175.000
# 5946  {'analyst_tools': ['power bi'], 'cloud': ['sno...            140080.000
# 5949  {'analyst_tools': ['excel', 'tableau'], 'progr...            164800.000
# 6046  {'libraries': ['pytorch', 'tensorflow', 'keras...            118450.000
# 6233  {'cloud': ['aws', 'redshift'], 'libraries': ['...            154500.000
# 6263  {'cloud': ['aws', 'azure', 'redshift'], 'datab...            169950.000
# 6305  {'analyst_tools': ['tableau', 'excel'], 'cloud...            175100.000
# 6325  {'analyst_tools': ['power bi'], 'cloud': ['gcp...            151925.000
# 6350  {'cloud': ['aws', 'redshift'], 'libraries': ['...            257500.000
# 6382  {'cloud': ['azure', 'snowflake', 'databricks']...            113300.000
# 6431  {'cloud': ['aws'], 'os': ['windows'], 'other':...             99663.315
# 6442  {'cloud': ['azure'], 'programming': ['sql', 'p...            141625.000
# 6471  {'analyst_tools': ['tableau', 'alteryx'], 'pro...            135960.000
# 6496  {'libraries': ['spark'], 'programming': ['pyth...            135450.000
# 6500  {'libraries': ['airflow'], 'programming': ['sq...            149164.600
# 6525  {'analyst_tools': ['tableau'], 'programming': ...             64890.000
# 6567  {'libraries': ['spark', 'tidyverse', 'pandas',...             58401.000
# 6575  {'analyst_tools': ['sas'], 'libraries': ['spar...            181561.705
# 6615  {'analyst_tools': ['tableau', 'power bi', 'sap...            103000.000
# 6707  {'analyst_tools': ['sas'], 'libraries': ['gdpr...             58401.000
# 6748                     {'analyst_tools': ['outlook']}            108150.000
# 6755  {'analyst_tools': ['excel'], 'programming': ['...             92700.000
# 6825  {'analyst_tools': ['sas', 'spss', 'tableau', '...             88240.950
# 6828  {'analyst_tools': ['sas'], 'programming': ['sq...            113300.000
# 6880  {'libraries': ['spark'], 'programming': ['r', ...            241020.000
# 6895  {'cloud': ['aws'], 'libraries': ['pyspark'], '...            194250.000
# 6941  {'analyst_tools': ['ssis', 'power bi', 'dax'],...            151925.000
# 7001  {'programming': ['sql', 'python', 'r'], 'webfr...            139033.520
# 7006                             {'programming': ['c']}            143325.000
# 7081  {'analyst_tools': ['sas', 'tableau', 'power bi...             78287.210
# 7090  {'cloud': ['aws'], 'programming': ['python', '...            292536.480
# 7092                                               None            294065.000
# 7095                             {'programming': ['r']}            127462.500
# 7118                                               None            172525.000
# 7140  {'analyst_tools': ['tableau'], 'cloud': ['data...            130725.000
# 7170  {'other': ['flow'], 'programming': ['java', 'p...             93555.000
