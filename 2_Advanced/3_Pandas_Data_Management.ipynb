# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# To display random samples of data
df.sample(10, random_state =42)
# Out:
#               job_title_short                             job_title  \
# 266130          Data Engineer       Midlevel o Senior Data Engineer
# 679340          Data Engineer     Data Engineer - AWS, Azure or GCP
# 114748          Data Engineer                         Data Engineer
# 269897           Data Analyst          Tobania - Senior BI Engineer
# 672509  Senior Data Scientist                 Senior Data Scientist
# 41768            Data Analyst                   Data System Analyst
# 720504          Data Engineer  DATA SCIENCE ENGINEERING MANAGER F/H
# 385013         Data Scientist      Data Scientist - Ob/Gyn Research
# 718765          Data Engineer                Lead/Sr. Data Engineer
# 375326          Data Engineer   Data Engineer Mid - Fort Belvoir VA
#
#              job_location              job_via job_schedule_type  \
# 266130    Santiago, Chile            via BeBee         Temp work
# 679340           Anywhere         via LinkedIn         Full-time
# 114748        Fairfax, VA         via LinkedIn         Full-time
# 269897  Brussels, Belgium   via BeBee Belgique         Full-time
# 672509     United Kingdom            via BeBee         Full-time
# 41768     Los Angeles, CA           via Indeed         Full-time
# 720504      Massy, France           via Indeed         Full-time
# 385013        Houston, TX  via Hire Generation         Full-time
# 718765           Anywhere         via LinkedIn         Full-time
# 375326   Fort Belvoir, VA     via ZipRecruiter         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 266130               False                      Chile 2023-10-09 07:45:58
# 679340                True                    Belgium 2023-05-31 11:03:43
# 114748               False                      Sudan 2023-07-21 09:02:50
# 269897               False                    Belgium 2023-06-29 08:15:07
# 672509               False             United Kingdom 2023-11-17 10:15:42
# 41768                False  California, United States 2023-10-17 06:00:48
# 720504               False                     France 2023-03-03 21:29:01
# 385013               False                      Sudan 2023-04-28 18:56:05
# 718765                True                    Georgia 2023-02-02 22:03:12
# 375326               False                      Sudan 2023-08-05 19:41:17
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 266130                   True                 False           Chile
# 679340                   True                 False         Belgium
# 114748                  False                 False           Sudan
# 269897                   True                 False         Belgium
# 672509                  False                 False  United Kingdom
# 41768                   False                 False   United States
# 720504                  False                 False          France
# 385013                  False                 False           Sudan
# 718765                  False                 False   United States
# 375326                  False                 False           Sudan
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 266130        None              NaN              NaN
# 679340        None              NaN              NaN
# 114748        None              NaN              NaN
# 269897        None              NaN              NaN
# 672509        None              NaN              NaN
# 41768         year         158950.0              NaN
# 720504        None              NaN              NaN
# 385013        None              NaN              NaN
# 718765        None              NaN              NaN
# 375326        None              NaN              NaN
#
#                                            company_name  \
# 266130                                         23people
# 679340                                            Orbis
# 114748                                              CGI
# 269897                                          Tobania
# 672509                              Wenham Carter Group
# 41768                                       UCLA Health
# 720504                                        Carrefour
# 385013                                Houston Methodist
# 718765                               Smart IT Frame LLC
# 375326  Veteran Jobs - 2023 Mar 01 - Veterans Resources
#
#                                                job_skills  \
# 266130               ['sql', 'python', 'java', 'airflow']
# 679340  ['python', 'aws', 'azure', 'gcp', 'tableau', '...
# 114748                                       ['c', 'aws']
# 269897  ['python', 'sql', 'databricks', 'snowflake', '...
# 672509  ['sql', 'python', 'mongodb', 'mongodb', 'postg...
# 41768   ['sql', 'sql server', 'oracle', 'tableau', 'ex...
# 720504  ['python', 'bigquery', 'spark', 'airflow', 'ku...
# 385013                                               None
# 718765               ['sql', 'aws', 'kafka', 'terraform']
# 375326          ['sql', 'nosql', 'airflow', 'sharepoint']
#
#                                           job_type_skills
# 266130  {'libraries': ['airflow'], 'programming': ['sq...
# 679340  {'analyst_tools': ['tableau', 'qlik', 'sap', '...
# 114748           {'cloud': ['aws'], 'programming': ['c']}
# 269897  {'analyst_tools': ['power bi'], 'cloud': ['dat...
# 672509  {'databases': ['mongodb', 'postgresql'], 'libr...
# 41768   {'analyst_tools': ['tableau', 'excel', 'ssrs',...
# 720504  {'cloud': ['bigquery'], 'libraries': ['spark',...
# 385013                                               None
# 718765  {'cloud': ['aws'], 'libraries': ['kafka'], 'ot...
# 375326  {'analyst_tools': ['sharepoint'], 'libraries':...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print(f"ID of df_original:                {id(df_original)}")
print(f"ID of df_altered:                 {id(df_altered)}")
print(f"Are the two dataframes the same?  {id(df_original) == id(df_altered)}")
# Out:
# ID of df_original:                6058523088
# ID of df_altered:                 13053250448
# Are the two dataframes the same?  False

# %%
median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
